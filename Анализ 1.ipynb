# %% [markdown]
# # Анализ результатов расчетов OLGA
#
# Файл с анализом результатов массовых расчетов режима работы трубопровода в OLGA
#
# версия 0.1 от 02.10.2017

# %%
""" импортируем библиотеки необходимые для проведения расчетов"""
import tplread as tp
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Читаем данные из каталога с результатам расчетов

# %%
t = tp.TplParams('tpl/')
t.read_data()
t.calc_data()
#print(t.df_super)
# Out:
# 144 файла найдено.
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . read done
# 1

# %% [markdown]
# Посмотрим, какие данные были прочитаны

# %%
# перечень файлов и параметров для которых что то загружено
print(len(t.files)," файла прочитано")
print(t.key_list)
print(t.key_list_all)
print(t.pipe_list)
print(t.p_end_list)
print(t.qliq_list)
print(t.qgas_list)
# Out:
# 144  файла прочитано
# ['HOLEXP', 'USFEXP', 'USL', 'USG']
# ['HOL' 'HOLEXP' 'ID' 'LSBEXP' 'LSLEXP' 'PT' 'QG' 'QGST' 'QLST' 'QOST' 'QT'
#  'TM' 'TU' 'UG' 'UL' 'USFEXP' 'USG' 'USL' 'USLT' 'USTEXP']
# ['Pipe-3' 'Pipe-5' 'Pipe-7' 'Pipe-11' 'Pipe-13' 'Pipe-17' 'Pipe-19'
#  'Pipe-21' 'Pipe-23']
# [  5.  10.  15.]
# [  5000.  10000.  15000.  20000.  25000.  30000.]
# [  1.   3.   5.   7.   9.  11.  13.  15.]

# %%
t.get_trend(key_list=['USL'],p_end_list=[5],point_list=['Pipe-17','Pipe-5'],q_gas_list=[13],q_liq_list=[20000,10000]).plot()

# %%
for pp in t.pipe_list:
    print(pp)
    a=t.get_matr_ql_qg(pipe=pp,p_end=10,val='mech')
    sns.heatmap(a,cmap="YlGnBu", vmin=0, vmax=10)
    show()
# Out:
# Pipe-3
# C:\Anaconda3\lib\site-packages\pandas\core\base.py:331: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   return self.obj.drop(self.exclusions, axis=1)
# Pipe-5
# Pipe-7
# Pipe-11
# Pipe-13
# Pipe-17
# Pipe-19
# Pipe-21
# Pipe-23
